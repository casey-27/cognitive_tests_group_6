# %% [markdown]
# # Spatial Reasoning Test
# ### Press play on the cell below to run the test

# %%
# %run Spatial_v1_2_1.py
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Downloads\Spatial_v1_2_1.py:404
#     402     compare_to_mean(time_taken, grade)
#     403     return display(html_outro) #Result displayed as % of correct answers
# --> 404 spatial_test(df_cubes)
#
# File ~\Downloads\Spatial_v1_2_1.py:382, in spatial_test(df_cubes)
#     380 panel = widgets.HBox([btn1, btn2, btn3, btn4])
#     381 display(panel)
# --> 382 ans = wait_for_event(timeout=200)
#     383 clear_output()
#     384 #bar.update(1)
#
# File ~\Downloads\Spatial_v1_2_1.py:115, in wait_for_event(timeout, interval, max_rate, allow_interupt)
#     111             keep_looping = False
#     113         # add pause before looping
#     114         # to check events again
# --> 115         time.sleep(interval)
#     117 # return event description after wait ends
#     118 # will be set to empty string '' if no event occured
# ...
